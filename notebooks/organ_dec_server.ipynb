# %%
#import pymeshlab

# %% [markdown]
# # Imports

# %%
import subprocess, re, os, sys
import matplotlib.pyplot as plt
import nibabel as nib
import os
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import pyvista
from skimage.measure import marching_cubes
import numpy as np
import shutil
from itertools import permutations
import json
#import open3d as o3d

# %%
import open3d as o3d

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# GPU picking
# http://stackoverflow.com/a/41638727/419116
# Nvidia-smi GPU memory parsing.
# Tested on nvidia-smi 370.23

def run_command(cmd):
    """Run command, return output as string."""
    
    output = subprocess.Popen(cmd, stdout=subprocess.PIPE, shell=True).communicate()[0]
    return output.decode("ascii")

def list_available_gpus():
    """Returns list of available GPU ids."""
    
    output = run_command("nvidia-smi -L")
    # lines of the form GPU 0: TITAN X
    gpu_regex = re.compile(r"GPU (?P<gpu_id>\d+):")
    result = []
    for line in output.strip().split("\n"):
        m = gpu_regex.match(line)
        assert m, "Couldnt parse "+line
        result.append(int(m.group("gpu_id")))
    return result

def gpu_memory_map():
    """Returns map of GPU id to memory allocated on that GPU."""

    output = run_command("nvidia-smi")
    gpu_output = output[output.find("GPU Memory"):]
    # lines of the form
    # |    0      8734    C   python                                       11705MiB |
    memory_regex = re.compile(r"[|]\s+?(?P<gpu_id>\d+)\D+?(?P<pid>\d+).+[ ](?P<gpu_memory>\d+)MiB")
    rows = gpu_output.split("\n")
    result = {gpu_id: 0 for gpu_id in list_available_gpus()}
    for row in gpu_output.split("\n"):
        m = memory_regex.search(row)
        if not m:
            continue
        gpu_id = int(m.group("gpu_id"))
        gpu_memory = int(m.group("gpu_memory"))
        result[gpu_id] += gpu_memory
    return result

def pick_gpu_lowest_memory():
    """Returns GPU with the least allocated memory"""

    memory_gpu_map = [(memory, gpu_id) for (gpu_id, memory) in gpu_memory_map().items()]
    best_memory, best_gpu = sorted(memory_gpu_map)[0]
    return best_gpu

def setup_one_gpu():
    assert not 'tensorflow' in sys.modules, "GPU setup must happen before importing TensorFlow"
    gpu_id = pick_gpu_lowest_memory()
    print("Picking GPU "+str(gpu_id))
    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
    os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

def setup_no_gpu():
    if 'tensorflow' in sys.modules:
        print("Warning, GPU setup must happen before importing TensorFlow")
    os.environ["CUDA_VISIBLE_DEVICES"] = ''

# %%
setup_one_gpu()
# Out:
# Picking GPU 1

# %% [markdown]
# # Functions

# %%
def pad_edge_list(edges):
    padding = np.ones(edges.shape[0], int)*3
    edges_w_padding = np.vstack((padding, edges.T)).T
    return edges_w_padding

def organs_data(abdominal_segmentations_data, dir):
    try:
        verts1, faces1, norms1, vals1 = marching_cubes(abdominal_segmentations_data==1, level=0, step_size=1)
        #verts2, faces2, norms2, vals2 = marching_cubes(abdominal_segmentations_data==2, level=0, step_size=1)
        #verts3, faces3, norms3, vals3 = marching_cubes(abdominal_segmentations_data==3, level=0, step_size=1)
        #verts4, faces4, norms4, vals4 = marching_cubes(abdominal_segmentations_data==4, level=0, step_size=1)
        #verts5, faces5, norms5, vals5 = marching_cubes(abdominal_segmentations_data==5, level=0, step_size=1)
        verts1 = verts1/np.array(abdominal_segmentations_data.shape) 
        #verts2 = verts2/np.array(abdominal_segmentations_data.shape) 
        #verts3 = verts3/np.array(abdominal_segmentations_data.shape) 
        #verts4 = verts4/np.array(abdominal_segmentations_data.shape) # to normalize ponit coordinate in [0,1]
        #verts5 = verts5/np.array(abdominal_segmentations_data.shape) # to normalize ponit coordinate in [0,1]
        edges1 = np.concatenate((faces1[:,:2], faces1[:,1:]), axis=0)
        #edges2 = np.concatenate((faces2[:,:2], faces2[:,1:]), axis=0)
        #edges3 = np.concatenate((faces3[:,:2], faces3[:,1:]), axis=0)
        #edges4 = np.concatenate((faces4[:,:2], faces4[:,1:]), axis=0)
        #edges5 = np.concatenate((faces5[:,:2], faces5[:,1:]), axis=0)

        lines1 = np.concatenate((np.int32(2*np.ones((edges1.shape[0],1))), edges1), 1)
        #lines2 = np.concatenate((np.int32(2*np.ones((edges2.shape[0],1))), edges2), 1)
        #lines3 = np.concatenate((np.int32(2*np.ones((edges3.shape[0],1))), edges3), 1)
        #lines4 = np.concatenate((np.int32(2*np.ones((edges4.shape[0],1))), edges4), 1)
        #lines5 = np.concatenate((np.int32(2*np.ones((edges5.shape[0],1))), edges5), 1)
        mesh1 = pyvista.PolyData(verts1, pad_edge_list(faces1))
        #mesh2 = pyvista.PolyData(verts2, pad_edge_list(faces2))
        #mesh3 = pyvista.PolyData(verts3, pad_edge_list(faces3))
        #mesh4 = pyvista.PolyData(verts4, pad_edge_list(faces4))
        #mesh5 = pyvista.PolyData(verts5, pad_edge_list(faces5))

        mesh1.lines = lines1.flatten()
        #mesh2.lines = lines2.flatten()
        #mesh3.lines = lines3.flatten()
        #mesh4.lines = lines4.flatten()
        #mesh5.lines = lines5.flatten()

        # verts = [verts1, verts2, verts3, verts4, verts5]
        # edges = [edges1, edges2, edges3, edges4, edges5]
        # faces = [faces1, faces2, faces3, faces4, faces5]
        # lines = [lines1, lines2, lines3, lines4, lines5]
        # meshes = [mesh1, mesh2, mesh3, mesh4, mesh5]
        # norms = [norms1, norms2, norms3, norms4, norms5]
        # vals = [vals1, vals2, vals3, vals4, vals5]

        verts = [verts1]
        edges = [edges1]
        faces = [faces1]
        lines = [lines1]
        meshes = [mesh1]
        norms = [norms1]
        vals = [vals1]

        data = [verts, edges, faces, lines, meshes, norms, vals]
        return data
    except:
        x=0

def triangle_mesh(verts, faces):
    mesh_list = []
    for i in range(0, len(verts)):
        mesh_list.append(o3d.geometry.TriangleMesh(vertices = o3d.utility.Vector3dVector(np.asarray(verts[i])), triangles = o3d.utility.Vector3iVector(np.asarray(faces[i]))))
        #mesh.compute_vertex_normals()
        #mesh.paint_uniform_color([0, 1, 0])
        #vis = o3d.visualization.Visualizer()
        #vis.create_window()
        #vis.add_geometry(mesh)
        #vis.update_geometry()
        #vis.poll_events()
        #vis.update_renderer()
        #path = str(i) + ".jpg"
        #vis.capture_screen_image(path)
        #vis.destroy_window()

    return mesh_list

def get_min_point_triangle():
    min_vertices = [np.nan, np.nan, np.nan, np.nan, np.nan]
    min_triangles = [np.nan, np.nan, np.nan, np.nan, np.nan]
    sum_vertices = [0,0,0,0,0]
    sum_triangles = [0,0,0,0,0]
    count = [0,0,0,0,0]
    min_vertices_mesh = [np.nan, np.nan, np.nan, np.nan, np.nan]
    min_triangles_mesh = [np.nan, np.nan, np.nan, np.nan, np.nan]
    empty_files = []
    bad_qual = []
    path_to_segmentations = "organ_segmentations"
    for _root, dirs, _file_list in os.walk(path_to_segmentations):
        for dir in dirs:
            if(os.path.exists(os.path.join(path_to_segmentations, dir, "prd.nii.gz"))):
                abdominal_segmentations = nib.load(os.path.join(path_to_segmentations, dir, "prd.nii.gz"))
                abdominal_segmentations_data = abdominal_segmentations.get_fdata()

                data = organs_data(abdominal_segmentations_data, dir)
                if(data is not None):
                    mesh_list = triangle_mesh(data[0], data[2])
                    
                    for i in range(0, len(mesh_list)):
                        sum_vertices[i] = sum_vertices[i] + len(np.asarray(mesh_list[i].vertices)) 
                        sum_triangles[i] = sum_triangles[i] + len(np.asarray(mesh_list[i].triangles))
                        count[i] = count[i] + 1 
                        if(len(np.asarray(mesh_list[i].vertices)) < 2000):
                            print("Less than 2000 points: {}".format(dir))
                            bad_qual.append(dir)
                        else:
                            if(np.isnan(min_triangles[i])):
                                min_triangles[i] = len(np.asarray(mesh_list[i].triangles))
                                min_triangles_mesh[i] = dir
                            if(len(np.asarray(mesh_list[i].triangles)) < min_triangles[i]):
                                min_triangles[i] = len(np.asarray(mesh_list[i].triangles))
                                min_triangles_mesh[i] = dir

                            if(np.isnan(min_vertices[i])):
                                min_vertices[i] = len(np.asarray(mesh_list[i].vertices))
                                min_vertices_mesh[i] = dir
                            if(len(np.asarray(mesh_list[i].vertices)) < min_vertices[i]):
                                min_vertices[i] = len(np.asarray(mesh_list[i].vertices))
                                min_vertices_mesh[i] = dir
            else:
                empty_files.append(dir)

    minimums = [min_vertices, min_triangles]
    vert_avg = [i / j for i, j in zip(sum_vertices, count)]
    triangle_avg = [[i / j for i, j in zip(sum_triangles, count)]]
    averages = [vert_avg, triangle_avg]
    files = [min_vertices_mesh, min_triangles_mesh]
    return files, minimums, averages, empty_files, bad_qual
            
    
def dec_triangle_mesh(dec):
    path_to_segmentations = "organ_segmentations"
    for _root, dirs, _file_list in os.walk(path_to_segmentations):
        for dir in dirs:
            if(not os.path.exists(os.path.join("./organ_decimations_off", str(dir) , "liver_mesh.off"))):
                if(os.path.exists(os.path.join(path_to_segmentations, dir, "prd.nii.gz"))):
                    abdominal_segmentations = nib.load(os.path.join(path_to_segmentations, dir, "prd.nii.gz"))
                    abdominal_segmentations_data = abdominal_segmentations.get_fdata()

                    data = organs_data(abdominal_segmentations_data, dir)
                    if(data is not None):
                        mesh_list = triangle_mesh(data[0], data[2])

                        for i in range(0, len(mesh_list)):
                            dec_mesh = o3d.geometry.TriangleMesh.simplify_quadric_decimation(mesh_list[i], dec)
                            dec_mesh_path = os.path.join("./organ_decimations_off", dir, "liver_mesh.off")
                            if(not os.path.exists(os.path.join("./organ_decimations_off", str(dir)))):
                                os.mkdir("./organ_decimations_off/" + str(dir))
                            o3d.io.write_triangle_mesh(dec_mesh_path, dec_mesh, print_progress=True)
    
    #for i in range(0, len(verts)):
    #    mesh = o3d.geometry.TriangleMesh(vertices = o3d.utility.Vector3dVector(np.asarray(verts[i])), triangles = o3d.utility.Vector3iVector(np.asarray(faces[i])))
    #    dec_mesh = o3d.geometry.TriangleMesh.simplify_quadric_decimation(mesh, dec)
    #dec_mesh.compute_vertex_normals()
    #dec_mesh.paint_uniform_color([0, 1, 0])
    #vis = o3d.visualization.Visualizer()
    #vis.create_window()
    #vis.add_geometry(dec_mesh)
    # vis.update_geometry()
    #vis.poll_events()
    #vis.update_renderer()
    #path = "dec_" + str(dec) + "_" + str(i) + ".jpg"
    #vis.capture_screen_image(path)
    #vis.destroy_window()
    # return mesh_list, dec_mesh_list

def off_to_json():
    path = "organ_decimations_off"
    for _root, dirs, _file_list in os.walk(path):
        for dir in dirs:
            if(os.path.exists(os.path.join(path, dir, "liver_mesh.off"))):
                if(not os.path.exists(os.path.join("./organ_decimations_json", str(dir) , "liver_mesh.off"))):
                    file = open("./organ_decimations_off/" + str(dir) + "/liver_mesh.off", "r")
                    lines_list = file.readlines()
                    file_info = lines_list[1].split(" ")
                    points_list = lines_list[2:(int(file_info[0])+2)]
                    faces_list = lines_list[(int(file_info[0])+2):]

                    split_points_list = []
                    for point in points_list:
                        new_structure = point.split(" ")
                        new_structure[2] = new_structure[2][:-1]
                        split_points_list.append(new_structure)

                    split_faces_list = []
                    for face in faces_list:
                        new_structure = face.split(" ")[1:]
                        new_structure[2] = new_structure[2][:-1]
                        split_faces_list.append(new_structure)

                    edges = []
                    for face in split_faces_list:
                        comb = permutations(face, 2)
                        for i in list(comb):
                            edges.append(i)

                    json_data = {
                        "data_points": split_points_list,
                        "edges": edges
                    }

                    json_file = json.dumps(json_data)
                    if(not os.path.exists(os.path.join("./organ_decimations_json", str(dir)))):
                        os.mkdir("./organ_decimations_json/" + str(dir))
                    with open("./organ_decimations_json/" + str(dir) + "/liver_mesh.json", "w") as outfile:
                        outfile.write(json_file)
                    shutil.rmtree(os.path.join("./organ_decimations_off", str(dir)))
    print("Done")

# %% [markdown]
# # Pyvista

# %%
path_to_segmentations = "organ_segmentations"
subj_id = 6019150
abdominal_segmentations = nib.load(os.path.join(path_to_segmentations, str(subj_id), "prd.nii.gz"))
abdominal_segmentations_data = abdominal_segmentations.get_fdata()

verts1, faces1, norms1, vals1 = marching_cubes(abdominal_segmentations_data==1, level=0, step_size=1)
verts2, faces2, norms2, vals2 = marching_cubes(abdominal_segmentations_data==2, level=0, step_size=1)
verts3, faces3, norms3, vals3 = marching_cubes(abdominal_segmentations_data==3, level=0, step_size=1)
verts4, faces4, norms4, vals4 = marching_cubes(abdominal_segmentations_data==4, level=0, step_size=1)
verts5, faces5, norms5, vals5 = marching_cubes(abdominal_segmentations_data==5, level=0, step_size=1)
verts1 = verts1/np.array(abdominal_segmentations_data.shape) 
verts2 = verts2/np.array(abdominal_segmentations_data.shape) 
verts3 = verts3/np.array(abdominal_segmentations_data.shape) 
verts4 = verts4/np.array(abdominal_segmentations_data.shape) # to normalize ponit coordinate in [0,1]
verts5 = verts5/np.array(abdominal_segmentations_data.shape) # to normalize ponit coordinate in [0,1]
edges1 = np.concatenate((faces1[:,:2], faces1[:,1:]), axis=0)
edges2 = np.concatenate((faces2[:,:2], faces2[:,1:]), axis=0)
edges3 = np.concatenate((faces3[:,:2], faces3[:,1:]), axis=0)
edges4 = np.concatenate((faces4[:,:2], faces4[:,1:]), axis=0)
edges5 = np.concatenate((faces5[:,:2], faces5[:,1:]), axis=0)

pyvista.set_plot_theme("document")
plotter = pyvista.Plotter(shape=(1, 1), window_size=[1000, 500], border=False)
plotter.subplot(0, 0)
lines1 = np.concatenate((np.int32(2*np.ones((edges1.shape[0],1))), edges1), 1)
lines2 = np.concatenate((np.int32(2*np.ones((edges2.shape[0],1))), edges2), 1)
lines3 = np.concatenate((np.int32(2*np.ones((edges3.shape[0],1))), edges3), 1)
lines4 = np.concatenate((np.int32(2*np.ones((edges4.shape[0],1))), edges4), 1)
lines5 = np.concatenate((np.int32(2*np.ones((edges5.shape[0],1))), edges5), 1)
mesh1 = pyvista.PolyData(verts1, pad_edge_list(faces1))
mesh2 = pyvista.PolyData(verts2, pad_edge_list(faces2))
mesh3 = pyvista.PolyData(verts3, pad_edge_list(faces3))
mesh4 = pyvista.PolyData(verts4, pad_edge_list(faces4))
mesh5 = pyvista.PolyData(verts5, pad_edge_list(faces5))

mesh1.lines = lines1.flatten()
mesh2.lines = lines2.flatten()
mesh3.lines = lines3.flatten()
mesh4.lines = lines4.flatten()
mesh5.lines = lines5.flatten()
plotter.add_mesh(mesh1, render_points_as_spheres=False, color="lightcoral", show_edges=True, line_width=1, edge_color='mediumorchid', point_size=2, )
plotter.add_mesh(mesh2, render_points_as_spheres=False, color="#ad4dff", show_edges=True, line_width=1, edge_color='mediumorchid', point_size=0.4)
plotter.add_mesh(mesh3, render_points_as_spheres=False, color="#409aff", show_edges=True, line_width=1, edge_color='mediumorchid', point_size=0.4)
plotter.add_mesh(mesh4, render_points_as_spheres=False, color="#409aff", show_edges=True, line_width=1, edge_color='mediumorchid', point_size=0.4)
plotter.add_mesh(mesh5, render_points_as_spheres=False, color="#ffcd00", show_edges=True, line_width=1, edge_color='mediumorchid', point_size=0.4)

plotter.camera.zoom(7)
# plotter.fly_to((0,-0.6, 0))
plotter.set_position((0,-5,2))
plotter.save_graphic("organ_meshes.svg")  
#plotter.show()


verts = [verts1, verts2, verts3, verts4, verts5]
edges = [edges1, edges2, edges3, edges4, edges5]
faces = [faces1, faces2, faces3, faces4, faces5]
lines = [lines1, lines2, lines3, lines4, lines5]
meshes = [mesh1, mesh2, mesh3, mesh4, mesh5]
norms = [norms1, norms2, norms3, norms4, norms5]
vals = [vals1, vals2, vals3, vals4, vals5]

mesh = o3d.geometry.TriangleMesh(vertices = o3d.utility.Vector3dVector(np.asarray(verts2)), triangles = o3d.utility.Vector3iVector(np.asarray(faces2)))
mesh
# Out:
# TriangleMesh with 4550 points and 9096 triangles.

# %% [markdown]
# # open3D

# %%
# with open3d: point cloud
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(np.asarray(verts1))

o3d.visualization.draw_geometries([pcd])
# Out:
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.

# %%
# with open3d: graph
lines = o3d.utility.Vector2iVector(np.asarray(edges1))
line_set = o3d.geometry.LineSet(
        points=o3d.utility.Vector3dVector(np.asarray(verts1)),
        lines=lines)

line_set.colors = o3d.utility.Vector3dVector([[1, 0, 0] for i in range(len(lines1))])

o3d.visualization.draw_geometries([line_set])
# Out:
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.

# %%
# with open3d: triangle mesh
mesh = o3d.geometry.TriangleMesh(vertices = o3d.utility.Vector3dVector(np.asarray(verts2)), triangles = o3d.utility.Vector3iVector(np.asarray(faces2)))
#mesh.compute_vertex_normals()
#mesh.paint_uniform_color([0, 1, 0]) 
#vis = o3d.visualization.Visualizer()
#vis.create_window()
#vis.add_geometry(mesh)
# vis.update_geometry()
#vis.poll_events()
#vis.update_renderer()
#path = "liver_mesh.jpg"
#vis.capture_screen_image(path)
#vis.destroy_window()
mesh
# o3d.visualization.draw_geometries([mesh])
# Out:
# TriangleMesh with 7904 points and 15804 triangles.

# %%
len(np.asarray(mesh.triangles))
# Out:
# 39076

# %%
len(np.asarray(mesh.vertices))
# Out:
# 19540

# %% [markdown]
# # Decimation

# %%
files, minimums, averages, empty_files, bad_qual = get_min_point_triangle()
# Out:
# Less than 2000 points: 3849529
# Less than 2000 points: 4602530
# Less than 2000 points: 5283486
# Less than 2000 points: 3271458
# Less than 2000 points: 5870022
# Less than 2000 points: 1286466
# Less than 2000 points: 1286466
# Less than 2000 points: 5631928
# Less than 2000 points: 3469204
# Less than 2000 points: 1881877
# Less than 2000 points: 1030350
# Less than 2000 points: 5559180
# Less than 2000 points: 3633588
# Less than 2000 points: 5353750
# Less than 2000 points: 5312364
# Less than 2000 points: 3734888
# Less than 2000 points: 5218617
# Less than 2000 points: 5660586
# Less than 2000 points: 4293892
# Less than 2000 points: 3618196
# Less than 2000 points: 2009066
# Less than 2000 points: 1361112
# Less than 2000 points: 2659432
# Less than 2000 points: 1134408
# Less than 2000 points: 5542421
# Less than 2000 points: 3116399
# Less than 2000 points: 5554979
# Less than 2000 points: 5613423
# Less than 2000 points: 5785102
# Less than 2000 points: 5298476
# Less than 2000 points: 2448916
# Less than 2000 points: 3141459
# Less than 2000 points: 2697252
# Less than 2000 points: 3195914
# Less than 2000 points: 3671635
# Less than 2000 points: 3508202
# Less than 2000 points: 2621343
# Less than 2000 points: 4163982
# Less than 2000 points: 1276105
# Less than 2000 points: 5849958
# Less than 2000 points: 4393356
# Less than 2000 points: 4194835
# Less than 2000 points: 2642484
# Less than 2000 points: 4546399
# Less than 2000 points: 1682389
# Less than 2000 points: 2490427
# Less than 2000 points: 1609911
# Less than 2000 points: 1727693
# Less than 2000 points: 1055531
# Less than 2000 points: 4638454
# Less than 2000 points: 5991077
# Less than 2000 points: 4692231
# Less than 2000 points: 1388855
# Less than 2000 points: 5398442
# Less than 2000 points: 5954425
# Less than 2000 points: 3442108
# Less than 2000 points: 1173277
# Less than 2000 points: 5905016
# Less than 2000 points: 1414283
# Less than 2000 points: 3567746
# Less than 2000 points: 1056495
# Less than 2000 points: 1529750
# Less than 2000 points: 1376347
# Less than 2000 points: 5207361
# Less than 2000 points: 3225302
# Less than 2000 points: 3205629
# Less than 2000 points: 4370591
# Less than 2000 points: 2241834
# Less than 2000 points: 1568266
# Less than 2000 points: 3545535
# Less than 2000 points: 2482522
# Less than 2000 points: 2239132
# Less than 2000 points: 2491863
# Less than 2000 points: 4848528
# Less than 2000 points: 1988403
# Less than 2000 points: 4024814
# Less than 2000 points: 2949922
# Less than 2000 points: 2485664
# Less than 2000 points: 1370062
# Less than 2000 points: 5888020
# Less than 2000 points: 5446444
# Less than 2000 points: 1868438
# Less than 2000 points: 1517869
# Less than 2000 points: 1695474
# Less than 2000 points: 2981916
# Less than 2000 points: 2625180
# Less than 2000 points: 1495885
# Less than 2000 points: 2702800
# Less than 2000 points: 3013334
# Less than 2000 points: 3013334
# Less than 2000 points: 4774205
# Less than 2000 points: 5927864
# Less than 2000 points: 4885973
# Less than 2000 points: 4885973
# Less than 2000 points: 1278272
# Less than 2000 points: 4686981
# Less than 2000 points: 4548967
# Less than 2000 points: 5168595
# Less than 2000 points: 4028729
# Less than 2000 points: 4574133
# Less than 2000 points: 2977377
# Less than 2000 points: 2977377
# Less than 2000 points: 5424329
# Less than 2000 points: 2098597
# Less than 2000 points: 4297978
# Less than 2000 points: 3901264
# Less than 2000 points: 5081704
# Less than 2000 points: 1585364
# Less than 2000 points: 4050670
# Less than 2000 points: 4361506
# Less than 2000 points: 5825376
# Less than 2000 points: 4919545
# Less than 2000 points: 3084095
# Less than 2000 points: 3285009
# Less than 2000 points: 1862956
# Less than 2000 points: 2967816
# Less than 2000 points: 5107155
# Less than 2000 points: 3234115
# Less than 2000 points: 2619119
# Less than 2000 points: 4422158
# Less than 2000 points: 3304428
# Less than 2000 points: 3520358
# Less than 2000 points: 2461591
# Less than 2000 points: 3300658
# Less than 2000 points: 4685332
# Less than 2000 points: 2311471
# Less than 2000 points: 3894571
# Less than 2000 points: 3074113
# Less than 2000 points: 2591375
# Less than 2000 points: 4495454
# Less than 2000 points: 5620015
# Less than 2000 points: 1833403
# Less than 2000 points: 3466078
# Less than 2000 points: 5641586
# Less than 2000 points: 2488458
# Less than 2000 points: 5630608
# Less than 2000 points: 3126669
# Less than 2000 points: 3608514
# Less than 2000 points: 5055125
# Less than 2000 points: 4845363
# Less than 2000 points: 3485892
# Less than 2000 points: 4983254
# Less than 2000 points: 1953677
# Less than 2000 points: 3828789
# Less than 2000 points: 4391786
# Less than 2000 points: 1621449
# Less than 2000 points: 4739867
# Less than 2000 points: 4549341
# Less than 2000 points: 1182813
# Less than 2000 points: 5376478
# Less than 2000 points: 5376478
# Less than 2000 points: 2827614
# Less than 2000 points: 5517685
# Less than 2000 points: 3596732
# Less than 2000 points: 1352955
# Less than 2000 points: 2970832
# Less than 2000 points: 4597273
# Less than 2000 points: 2372258
# Less than 2000 points: 2321631
# Less than 2000 points: 3004824
# Less than 2000 points: 2662817
# Less than 2000 points: 5136187
# Less than 2000 points: 4338527
# Less than 2000 points: 5911797
# Less than 2000 points: 5185712
# Less than 2000 points: 1144493
# Less than 2000 points: 1984375
# Less than 2000 points: 5615528
# Less than 2000 points: 1529946
# Less than 2000 points: 5739142
# Less than 2000 points: 4113674
# Less than 2000 points: 1507982
# Less than 2000 points: 5634093
# Less than 2000 points: 5856995
# Less than 2000 points: 5314573
# Less than 2000 points: 2336048
# Less than 2000 points: 3598289
# Less than 2000 points: 3598289
# Less than 2000 points: 3598289
# Less than 2000 points: 3151719
# Less than 2000 points: 3013580
# Less than 2000 points: 3260211
# Less than 2000 points: 1203234
# Less than 2000 points: 4272379
# Less than 2000 points: 4688818
# Less than 2000 points: 2478270
# Less than 2000 points: 4477420
# Less than 2000 points: 5891860
# Less than 2000 points: 5050883
# Less than 2000 points: 1575072
# Less than 2000 points: 1903522
# Less than 2000 points: 3045683
# Less than 2000 points: 1857732
# Less than 2000 points: 1857732
# Less than 2000 points: 5315568
# Less than 2000 points: 2408468
# Less than 2000 points: 3626303
# Less than 2000 points: 3626303
# Less than 2000 points: 3292139
# Less than 2000 points: 4662636
# Less than 2000 points: 1116489
# Less than 2000 points: 1114426
# Less than 2000 points: 2035935
# Less than 2000 points: 1836904
# Less than 2000 points: 4090007
# Less than 2000 points: 4369340
# Less than 2000 points: 5568431
# Less than 2000 points: 5730997
# Less than 2000 points: 5587038
# Less than 2000 points: 1397197
# Less than 2000 points: 4854352
# Less than 2000 points: 3850516
# Less than 2000 points: 1188194
# Less than 2000 points: 5208897
# Less than 2000 points: 5440105
# Less than 2000 points: 6005390
# Less than 2000 points: 5543847
# Less than 2000 points: 3047888
# Less than 2000 points: 6004606
# Less than 2000 points: 4026884
# Less than 2000 points: 4801451
# Less than 2000 points: 4847878
# Less than 2000 points: 3090562
# Less than 2000 points: 4651319
# Less than 2000 points: 3878846
# Less than 2000 points: 3596813
# Less than 2000 points: 5486672
# Less than 2000 points: 2347672
# Less than 2000 points: 3769295
# Less than 2000 points: 3981498
# Less than 2000 points: 1637252
# Less than 2000 points: 2612769
# Less than 2000 points: 3488580
# Less than 2000 points: 4307112
# Less than 2000 points: 5314127
# Less than 2000 points: 4713827
# Less than 2000 points: 3979007
# Less than 2000 points: 4741696
# Less than 2000 points: 1324025
# Less than 2000 points: 1454140
# Less than 2000 points: 1321892
# Less than 2000 points: 2119396
# Less than 2000 points: 3405327
# Less than 2000 points: 4602089
# Less than 2000 points: 4403821
# Less than 2000 points: 3350756
# Less than 2000 points: 3494344
# Less than 2000 points: 5743001
# Less than 2000 points: 3009639
# Less than 2000 points: 5226452
# Less than 2000 points: 4091046
# Less than 2000 points: 5842359
# Less than 2000 points: 5688791
# Less than 2000 points: 3711639
# Less than 2000 points: 3413627
# Less than 2000 points: 5635321
# Less than 2000 points: 2820963
# Less than 2000 points: 3652343
# Less than 2000 points: 4048738
# Less than 2000 points: 3216857
# Less than 2000 points: 1597012
# Less than 2000 points: 2040110
# Less than 2000 points: 2080416
# Less than 2000 points: 2285951
# Less than 2000 points: 1124473
# Less than 2000 points: 4886162
# Less than 2000 points: 2850256
# Less than 2000 points: 2317992
# Less than 2000 points: 2250638
# Less than 2000 points: 3293335
# Less than 2000 points: 5536033
# Less than 2000 points: 5557156
# Less than 2000 points: 3634223
# Less than 2000 points: 3818031
# Less than 2000 points: 2927236
# Less than 2000 points: 2690112
# Less than 2000 points: 5466740
# Less than 2000 points: 3203274
# Less than 2000 points: 2142695
# Less than 2000 points: 5502656
# Less than 2000 points: 5818304
# Less than 2000 points: 4256895
# Less than 2000 points: 2578377
# Less than 2000 points: 2983258
# Less than 2000 points: 1591925
# Less than 2000 points: 5074123
# Less than 2000 points: 3723736
# Less than 2000 points: 3054512
# Less than 2000 points: 5202275
# Less than 2000 points: 3817056
# Less than 2000 points: 2850386
# Less than 2000 points: 3084980
# Less than 2000 points: 4336632
# Less than 2000 points: 5060450
# Less than 2000 points: 1602667
# Less than 2000 points: 4794815
# Less than 2000 points: 5368026
# Less than 2000 points: 4085049
# Less than 2000 points: 4693423
# Less than 2000 points: 1341402
# Less than 2000 points: 4704019
# Less than 2000 points: 3182624
# Less than 2000 points: 3476942
# Less than 2000 points: 2176329
# Less than 2000 points: 4255759
# Less than 2000 points: 4714645
# Less than 2000 points: 1061762
# Less than 2000 points: 2501570
# Less than 2000 points: 3076152
# Less than 2000 points: 1987488
# Less than 2000 points: 2972630
# Less than 2000 points: 4834010
# Less than 2000 points: 2489010
# Less than 2000 points: 2643608
# Less than 2000 points: 2118334
# Less than 2000 points: 1242823
# Less than 2000 points: 5208371
# Less than 2000 points: 3206829
# Less than 2000 points: 4244472
# Less than 2000 points: 5116112
# Less than 2000 points: 3627598
# Less than 2000 points: 4882232
# Less than 2000 points: 3922124
# Less than 2000 points: 4173664
# Less than 2000 points: 4298153
# Less than 2000 points: 2445658
# Less than 2000 points: 2302375
# Less than 2000 points: 3188451
# Less than 2000 points: 3013073
# Less than 2000 points: 1794706
# Less than 2000 points: 2860248
# Less than 2000 points: 1522971
# Less than 2000 points: 5131494
# Less than 2000 points: 2728981
# Less than 2000 points: 4800121
# Less than 2000 points: 3282564
# Less than 2000 points: 3301787
# Less than 2000 points: 1342958
# Less than 2000 points: 4765897
# Less than 2000 points: 4849384
# Less than 2000 points: 3277812
# Less than 2000 points: 5803606
# Less than 2000 points: 4564135
# Less than 2000 points: 3874038
# Less than 2000 points: 1330576
# Less than 2000 points: 4230972
# Less than 2000 points: 4881100
# Less than 2000 points: 3845885
# Less than 2000 points: 1968184
# Less than 2000 points: 3140192
# Less than 2000 points: 3310632
# Less than 2000 points: 3275669
# Less than 2000 points: 4172377
# Less than 2000 points: 4542438
# Less than 2000 points: 2655697
# Less than 2000 points: 5983342
# Less than 2000 points: 3788088
# Less than 2000 points: 4910307
# Less than 2000 points: 2253067
# Less than 2000 points: 2825032
# Less than 2000 points: 5473798
# Less than 2000 points: 4461948
# Less than 2000 points: 4054028
# Less than 2000 points: 2408781
# Less than 2000 points: 1940507
# Less than 2000 points: 1794850
# Less than 2000 points: 1638812
# Less than 2000 points: 2520500
# Less than 2000 points: 3606462
# Less than 2000 points: 5805518
# Less than 2000 points: 4422602
# Less than 2000 points: 2554187
# Less than 2000 points: 2679902
# Less than 2000 points: 3227552
# Less than 2000 points: 5726742
# Less than 2000 points: 4016395
# Less than 2000 points: 3179612
# Less than 2000 points: 3850396
# Less than 2000 points: 3850396
# Less than 2000 points: 5665065
# Less than 2000 points: 5428601
# Less than 2000 points: 3971518
# Less than 2000 points: 1781632
# Less than 2000 points: 2921244
# Less than 2000 points: 1693341
# Less than 2000 points: 1456852
# Less than 2000 points: 5900710
# Less than 2000 points: 4313495
# Less than 2000 points: 3668891
# Less than 2000 points: 4701181
# Less than 2000 points: 5188489
# Less than 2000 points: 4266049
# Less than 2000 points: 1992167
# Less than 2000 points: 1739577
# Less than 2000 points: 5782423
# Less than 2000 points: 2255389
# Less than 2000 points: 1466559
# Less than 2000 points: 5820385
# Less than 2000 points: 2421026
# Less than 2000 points: 1893463
# Less than 2000 points: 3348002
# Less than 2000 points: 4468099
# Less than 2000 points: 5291549
# Less than 2000 points: 4049134
# Less than 2000 points: 5311572
# Less than 2000 points: 1875083
# Less than 2000 points: 3942927
# Less than 2000 points: 1263611
# Less than 2000 points: 2017827
# Less than 2000 points: 4174384
# Less than 2000 points: 4864409
# Less than 2000 points: 5380869
# Less than 2000 points: 4921505
# Less than 2000 points: 2998292
# Less than 2000 points: 4133100
# Less than 2000 points: 4700050
# Less than 2000 points: 4534774
# Less than 2000 points: 4859763
# Less than 2000 points: 3863017
# Less than 2000 points: 1906377
# Less than 2000 points: 5583550
# Less than 2000 points: 5415708
# Less than 2000 points: 1332069
# Less than 2000 points: 3509123
# Less than 2000 points: 3217127
# Less than 2000 points: 1446252
# Less than 2000 points: 4271621
# Less than 2000 points: 2638317
# Less than 2000 points: 1011101
# Less than 2000 points: 1001544
# Less than 2000 points: 2874678
# Less than 2000 points: 5263544
# Less than 2000 points: 3320723
# Less than 2000 points: 5561419
# Less than 2000 points: 2737891
# Less than 2000 points: 4135801
# Less than 2000 points: 1476653
# Less than 2000 points: 5932518
# Less than 2000 points: 1156821
# Less than 2000 points: 2765654
# Less than 2000 points: 1403653
# Less than 2000 points: 4961231
# Less than 2000 points: 5670399
# Less than 2000 points: 2806163
# Less than 2000 points: 4409338
# Less than 2000 points: 3941317
# Less than 2000 points: 4896055
# Less than 2000 points: 4520605
# Less than 2000 points: 4529814
# Less than 2000 points: 1197472
# Less than 2000 points: 3753576
# Less than 2000 points: 4998569
# Less than 2000 points: 4899191
# Less than 2000 points: 1390639
# Less than 2000 points: 5026388
# Less than 2000 points: 2584912
# Less than 2000 points: 1192728
# Less than 2000 points: 4194238
# Less than 2000 points: 5102736
# Less than 2000 points: 3731642
# Less than 2000 points: 3281534
# Less than 2000 points: 4329095
# Less than 2000 points: 1509869
# Less than 2000 points: 5800086
# Less than 2000 points: 2585032
# Less than 2000 points: 1783906
# Less than 2000 points: 3014341
# Less than 2000 points: 3900352
# Less than 2000 points: 3262126
# Less than 2000 points: 2600989
# Less than 2000 points: 3918585
# Less than 2000 points: 2853899
# Less than 2000 points: 2922784
# Less than 2000 points: 2607273
# Less than 2000 points: 4082944
# Less than 2000 points: 2464314
# Less than 2000 points: 2587206
# Less than 2000 points: 2502896
# Less than 2000 points: 1323489
# Less than 2000 points: 5614605
# Less than 2000 points: 3345777
# Less than 2000 points: 2937118
# Less than 2000 points: 2526518

# %%
len(empty_files)
# Out:
# 13352

# %%
files

# %%
minimums
# Out:
# [[2488, 6, 6, 22, 38], [4974, 8, 8, 40, 72]]

# %%
averages

# %%
bad_qual

# %%
len(bad_qual)

# %%
mlist = triangle_mesh(verts, faces)
mlist
# Out:
# [TriangleMesh with 17364 points and 34728 triangles.,
#  TriangleMesh with 3094 points and 6184 triangles.,
#  TriangleMesh with 4228 points and 8452 triangles.,
#  TriangleMesh with 3822 points and 7640 triangles.,
#  TriangleMesh with 3334 points and 6664 triangles.]

# %%
mesh = o3d.geometry.TriangleMesh(vertices = o3d.utility.Vector3dVector(np.asarray(verts1)), triangles = o3d.utility.Vector3iVector(np.asarray(faces1)))
dec_mesh = o3d.geometry.TriangleMesh.simplify_quadric_decimation(mesh, 4974)
#dec_mesh.compute_vertex_normals()
#dec_mesh.paint_uniform_color([0, 1, 0])
#vis = o3d.visualization.Visualizer()
#vis.create_window()
#vis.add_geometry(dec_mesh)
# vis.update_geometry()
#vis.poll_events()
#vis.update_renderer()
#path = "liver_20000_dec_mesh.jpg"
#vis.capture_screen_image(path)
#vis.destroy_window()
dec_mesh
# Out:
# TriangleMesh with 2573 points and 4973 triangles.

# %%
o3d.visualization.draw_geometries([dec_mesh])

# %%
dec_triangle_mesh(2000)
# Out:
# Writing OFF: [========================================] 100%

# %%
off_to_json()

# %% [markdown]
# # Visuals for all organs

# %%
triangle_mesh(verts, faces)

# %%
dec_triangle_mesh(verts, faces, 4000)

# %%
print(len(next(os.walk('organ_segmentations'))[1]))
# Out:
# 44205

# %%
print(len(next(os.walk('organ_decimations_off'))[1]))
# Out:
# 30721

# %%
print(len(next(os.walk('organ_decimations_json'))[1]))
